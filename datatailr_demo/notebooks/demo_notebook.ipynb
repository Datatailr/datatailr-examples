# %%
from datetime import date, datetime
import numpy as np
import pandas as pd
from perspective.widget import PerspectiveWidget

get_ipython().run_line_magic('load_ext', 'datatailr.scheduler.jupyter_magic')

N = 10_000
data = pd.DataFrame({
    "int": np.arange(N),
    "float": [i * 1.5 for i in range(N)],
    "bool": [True for i in range(N)],
    "date": [date.today() for i in range(N)],
    "datetime": [datetime.now() for i in range(N)],
    "string": [str(i) for i in range(N)]
})

# %% [markdown]
# ## Perspective Widget
#
# This is a demo of the Perspective Widget. Using the [perspective library](https://perspective-dev.github.io/), we can create a widget that displays a table of data or a chart.
#
# Perspective is an interactive analytics and data visualization component, which is especially well-suited for large and/or streaming datasets.
#
# Use it to create user-configurable reports, dashboards, notebooks and applications, then deploy stand-alone in the browser, or in concert with Python and/or Jupyterlab.

# %%
PerspectiveWidget(data, aggregates={"datetime": "any"}, sort=[["date", "desc"]])
# Out:
# PerspectiveWidget(aggregates={'datetime': 'any'}, binding_mode='server', columns=['index', 'int', 'float', 'bo…

# %% [markdown]
# ## Datatailr Workflow Explorer

# %%
# %dt_runs
# Out:
# <style>
# .dt-w {
#     font-family: 'Inter','Open Sans',system-ui,sans-serif; font-size:13px;
#     --dt-fg:       var(--jp-ui-font-color1, #596571);
#     --dt-fg-muted: var(--jp-ui-font-color2, #848e98);
#     --dt-fg-bold:  var(--jp-ui-font-color0, #3c4249);
#     --dt-bg:       var(--jp-layout-color1, #fff);
#     --dt-bg-alt:   var(--jp-layout-color2, #f5f6f8);
#     --dt-border:   var(--jp-border-color1, #e8eaed);
#     --dt-border-light: var(--jp-border-color2, #f0f1f3);
#     --dt-input-bg: var(--jp-layout-color1, #fff);
#     --dt-input-border: var(--jp-border-color1, #d2d9e1);
#     color: var(--dt-fg);
# }
# .dt-w * { box-sizing:border-box; }
#
# /* inputs */
# .dt-w .widget-dropdown>select,
# .dt-w .widget-datepicker>input,
# .dt-w .widget-timepicker>input,
# .dt-w .widget-inttext input {
#     border-radius:6px!important; border:1px solid var(--dt-input-border)!important;
#     background:var(--dt-input-bg)!important; color:var(--dt-fg)!important;
#     font-family:inherit!important; font-size:12px!important;
#     height:28px!important; padding:0 7px!important;
# }
# .dt-w .widget-dropdown>select { height:28px!important; }
# .dt-w .widget-dropdown>label,
# .dt-w .widget-inline-hbox>label,
# .dt-w .widget-inttext>label {
#     font-family:inherit!important; font-size:12px!important;
#     color:var(--dt-fg-muted)!important; font-weight:500!important;
#     line-height:28px!important; padding-right:4px!important;
# }
#
# /* buttons */
# .dt-w .widget-button {
#     border-radius:6px!important; border:1px solid var(--dt-input-border)!important;
#     background:var(--dt-bg)!important; font-family:inherit!important;
#     font-size:11px!important; font-weight:500!important;
#     color:var(--dt-fg)!important; height:28px!important; padding:0 8px!important;
#     cursor:pointer!important;
#     display:inline-flex!important; align-items:center!important;
#     justify-content:center!important; line-height:1!important;
# }
# .dt-w .widget-button:hover { background:var(--dt-bg-alt)!important; border-color:var(--dt-fg-muted)!important; }
# .dt-w .dt-accent {
#     background:#3aceac!important; border-color:#3aceac!important;
#     color:#fff!important; font-size:12px!important;
# }
# .dt-w .dt-accent:hover { background:#2fb893!important; border-color:#2fb893!important; }
#
# /* labels */
# .dt-w .widget-label {
#     font-family:inherit!important; font-size:13px!important; color:var(--dt-fg)!important;
# }
#
# /* run table */
# .dt-w .dt-table {
#     border:1px solid var(--dt-border)!important; border-radius:10px!important;
#     overflow:hidden!important;
# }
#
# /* toggle button for expanding a rerun group */
# .dt-w .dt-toggle {
#     border:none!important; background:transparent!important;
#     color:var(--dt-fg-muted)!important;
#     font-family:inherit!important; font-size:11px!important; font-weight:500!important;
#     padding:0 6px!important; height:22px!important; min-width:0!important;
# }
# .dt-w .dt-toggle:hover {
#     background:var(--dt-bg-alt)!important; color:var(--dt-fg)!important;
# }
#
# /* hint box */
# .dt-w .dt-hint {
#     background:var(--dt-bg-alt)!important; border-radius:8px!important;
#     padding:10px 14px!important; border:1px solid var(--dt-border)!important;
# }
# .dt-w .dt-hint .widget-label {
#     font-family:Monaco,'Courier New',monospace!important;
#     font-size:12px!important; color:var(--dt-fg-bold)!important;
# }
#
# .dt-w .dt-popup {
#     border:1px solid var(--dt-border)!important;
#     border-radius:10px!important;
#     padding:10px!important;
#     background:var(--dt-bg)!important;
#     box-shadow:0 4px 16px rgba(0, 0, 0, 0.10)!important;
#     width:fit-content!important;
# }
# .dt-w .dt-popup-title {
#     font-size:12px!important;
#     color:var(--dt-fg-bold)!important;
#     font-weight:600!important;
# }
#
# /* tabs */
# .dt-w .widget-tab>.p-TabBar .p-TabBar-tab {
#     font-family:inherit!important; font-size:12px!important; font-weight:500!important;
# }
#
# /* cytoscape graph - transparent background */
# [class*="cytoscape"] { background:transparent!important; }
# [class*="cytoscape"] > div { background:transparent!important; }
# [class*="cytoscape"] canvas { background:transparent!important; }
#
# /* scrollable tab pane */
# .dt-scroll-pane { max-height:400px!important; overflow-y:auto!important; overflow-x:auto!important; }
# .dt-scroll-pane .widget-output { overflow:visible!important; }
#
# /* utility: hide a widget reliably (display:none on a Tab parent isn't
#    always honored when set via Layout, so we force it via class). */
# .dt-w .dt-hidden { display:none!important; }
#
# /* notification surfaces */
# .dt-w .dt-error,
# .dt-w .dt-info {
#     border-radius:8px!important; padding:10px 14px!important;
#     border:1px solid var(--dt-border)!important;
#     font-family:inherit!important; font-size:12px!important;
# }
# .dt-w .dt-error {
#     background:rgba(255, 67, 68, 0.08)!important;
#     border-color:rgba(255, 67, 68, 0.35)!important;
#     color:#c0282a!important;
# }
# .dt-w .dt-info { background:var(--dt-bg-alt)!important; color:var(--dt-fg-muted)!important; }
# .dt-w .dt-placeholder {
#     color:var(--dt-fg-muted)!important; font-style:italic!important;
#     font-size:12px!important; padding:24px 12px!important; text-align:center!important;
# }
#
# /* preview header (shows which task/run is on screen) */
# .dt-w .dt-preview-header {
#     display:flex!important; align-items:center!important; gap:8px!important;
#     padding:6px 2px!important; flex-wrap:wrap!important;
# }
# .dt-w .dt-chip {
#     display:inline-flex!important; align-items:center!important;
#     height:22px!important; padding:0 9px!important; border-radius:9999px!important;
#     background:var(--dt-bg-alt)!important; color:var(--dt-fg-bold)!important;
#     border:1px solid var(--dt-border)!important;
#     font-size:11px!important; font-weight:500!important; white-space:nowrap!important;
# }
# .dt-w .dt-chip-mono {
#     font-family:Monaco,'Courier New',monospace!important;
#     color:var(--dt-fg-muted)!important;
# }
#
# /* log viewer */
# .dt-w .dt-log-block {
#     margin:0!important; padding:10px 12px!important;
#     background:var(--dt-bg-alt)!important; border:1px solid var(--dt-border)!important;
#     border-radius:8px!important;
#     font-family:Monaco,'Courier New',monospace!important;
#     font-size:11.5px!important; line-height:1.45!important;
#     color:var(--dt-fg-bold)!important;
#     white-space:pre-wrap!important; word-break:break-word!important;
#     max-height:380px!important; overflow:auto!important;
# }
#
# /* run id mono chip */
# .dt-w .dt-rid {
#     font-family:Monaco,'Courier New',monospace!important;
#     color:var(--dt-fg-muted)!important; font-size:12px!important;
# }
#
# /* pagination */
# .dt-w .dt-page-row {
#     display:inline-flex!important; align-items:center!important; gap:4px!important;
#     padding:4px 6px!important; border-radius:8px!important;
#     background:var(--dt-bg)!important; border:1px solid var(--dt-border)!important;
#     width:fit-content!important;
# }
# .dt-w .dt-page-row .widget-button[disabled],
# .dt-w .dt-page-row .widget-button:disabled {
#     opacity:0.4!important; cursor:default!important;
# }
#
# /* filter row labels */
# .dt-w .dt-filter-label {
#     display:inline-flex!important; align-items:center!important;
#     height:28px!important; padding:0 4px 0 6px!important;
#     font-size:12px!important; color:var(--dt-fg-muted)!important; font-weight:500!important;
# }
#
# /* blob storage explorer */
# .dt-w .dt-blob-tree {
#     border:1px solid var(--dt-border)!important; border-radius:10px!important;
#     overflow:auto!important; max-height:460px!important;
# }
# .dt-w .dt-blob-btn {
#     border:none!important; background:transparent!important;
#     color:var(--dt-fg)!important; font-family:inherit!important;
#     font-size:13px!important; font-weight:400!important;
#     text-align:left!important; justify-content:flex-start!important;
#     height:30px!important; padding:0 6px!important; min-width:0!important;
#     width:100%!important; box-shadow:none!important;
# }
# .dt-w .dt-blob-btn:hover { background:var(--dt-bg-alt)!important; }
# .dt-w .dt-blob-dir { font-weight:600!important; color:var(--dt-fg-bold)!important; }
# .dt-w .dt-blob-file { color:#4a90e2!important; }
# .dt-w .dt-blob
# VBox(children=(HBox(children=(Dropdown(description='Workflow:', layout=Layout(height='28px', width='340px'), o…

# %% [markdown]
# ## Interactive Dashboard

# %%
import numpy as np
from bqplot import pyplot as plt
import bqplot
import ipywidgets as widgets


n = 200

x = np.linspace(0.0, 10.0, n)
y = np.cumsum(np.random.randn(n)*10).astype(int)

label_selected = widgets.Label(value="Selected: 0")
fig = plt.figure( title='Histogram')
np.random.seed(0)
hist = plt.hist(y, bins=25)
hist.scales['sample'].min = float(y.min())
hist.scales['sample'].max = float(y.max())
display(fig)
fig.layout.width = 'auto'
fig.layout.height = 'auto'
fig.layout.min_height = '300px' # so it shows nicely in the notebook
fig.layout.flex = '1'
# Out:
# Figure(axes=[Axis(orientation='vertical', scale=LinearScale()), Axis(scale=LinearScale(max=6.0, min=-193.0))],…

# %%
fig = plt.figure( title='Line Chart')
np.random.seed(0)
n = 200
p = plt.plot(x, y)
fig
# Out:
# Figure(axes=[Axis(scale=LinearScale()), Axis(orientation='vertical', scale=LinearScale())], fig_margin={'top':…

# %%
fig.layout.width = 'auto'
fig.layout.height = 'auto'
fig.layout.min_height = '300px' # so it shows nicely in the notebook
fig.layout.flex = '1'

# %%
brushintsel = bqplot.interacts.BrushIntervalSelector(scale=p.scales['x'])

# %%
def update_range(*args):
    label_selected.value = "Selected range {}".format(brushintsel.selected)
    mask = (x > brushintsel.selected[0]) & (x < brushintsel.selected[1])
    hist.sample = y[mask]
    
brushintsel.observe(update_range, 'selected')
fig.interaction = brushintsel
